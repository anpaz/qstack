# %% [markdown]
# # `4.teleport` — Quantum teleportation
#
# This notebook is the MLIR-stack counterpart of
# [examples/4.teleport.ipynb](../../examples/4.teleport.ipynb).
#
# Quantum teleportation transfers the state of a *source* qubit to a
# *target* qubit using a shared EPR pair and two classical bits of
# communication. The protocol exercises a multi-branch
# `switch` over a host-language selector — the classical fan-out the
# qstack runtime is designed to expose explicitly.

# %%
# %load_ext qstack_mlir.jupyter

# %% [markdown]
# ## 1. The protocol
#
# `teleport(qubit target)` does four things:
#
# 1. Prepares the **source** qubit in some state (we use `x source` to
#    teleport $|1\rangle$).
# 2. Builds an EPR pair on `(shared, target)` using `h` + `cx`.
# 3. Does a Bell measurement on `(source, shared)`: `cx source, shared`,
#    `h source`, measure both into classical bits `m0` and `m1`.
# 4. Applies the Pauli correction $Z^{m_0} X^{m_1}$ to `target` via a
#    `switch` over a four-case `extern selector`. Each `case` is lowered
#    to its own continuation `func.func`; the runtime invokes the case
#    chosen by the selector.
#
# After `teleport` returns, the top-level `main` measures `target` in the
# computational basis. Because we teleported $|1\rangle$, every shot
# should read **1**.

# %%
# %%qasm teleport_mod
# QSTACKQASM 0.1;
# include "qstack/cliffords.inc";
#
# extern selector teleport_fix(bit, bit) -> int;
#
# def teleport(qubit target) {
#   qreg shared[1];
#   qreg source[1];
#   bit m0;
#   bit m1;
#
#   // Prepare source = X|0> = |1>.
#   x source[0];
#
#   // EPR pair on (shared, target).
#   h shared[0];
#   cx shared[0], target;
#
#   // Bell measurement on (source, shared).
#   cx source[0], shared[0];
#   h source[0];
#   measure source[0] -> m0;
#   measure shared[0] -> m1;
#
#   // Pauli correction Z^m0 X^m1 on `target`.
#   switch (teleport_fix(m0, m1)) {
#     case 0: { }
#     case 1: { x target; }
#     case 2: { z target; }
#     case 3: { x target; z target; }
#   }
# }
#
# qreg q[1];
# creg c[1];
# teleport q[0];
# measure q[0] -> c[0];

# %% [markdown]
# ## 2. Inspect the lowered IR
#
# Note the four auto-generated `__case_*` continuation functions — one
# per `case` arm — and the `qstack.select` op whose `continuations`
# attribute is the closed menu of labels the selector may return.

# %%
print(teleport_mod)

# %% [markdown]
# ## 3. Register the selector and run
#
# The `teleport_fix` selector is just a 2-bit → label table. The
# `Machine` invokes it once per `select`, looks the returned label up in
# the kernel's `continuations` menu, and runs the corresponding case
# function on the live qubits.

# %%
from qstack_mlir.runtime import CallbackRegistry, Machine

reg = CallbackRegistry()

@reg.selector("teleport_fix")
def _fix(*, b0, b1):
    # (m0, m1) -> case label "0"/"1"/"2"/"3".
    return str(b0 * 2 + b1)

machine = Machine(teleport_mod, num_qubits=8, registry=reg)
results = machine.shots("main", 2000)
results.plot_histogram()

# %% [markdown]
# The histogram concentrates entirely on `1` — the teleported $|1\rangle$
# state is faithfully reproduced on the target qubit, even though the
# Bell measurement outcomes `(m0, m1)` are uniformly random.
#
# ## 4. Teleporting a superposition
#
# We can also teleport $|+\rangle = H|0\rangle$. Since the target is then
# measured in the Z basis, the histogram should be a fair coin — which
# verifies that the *quantum* state (not just a classical bit) is what
# crossed the link.

# %%
# %%qasm teleport_plus
# QSTACKQASM 0.1;
# include "qstack/cliffords.inc";
#
# extern selector teleport_fix(bit, bit) -> int;
#
# def teleport(qubit target) {
#   qreg shared[1];
#   qreg source[1];
#   bit m0;
#   bit m1;
#
#   h source[0];  // prepare |+>
#
#   h shared[0];
#   cx shared[0], target;
#
#   cx source[0], shared[0];
#   h source[0];
#   measure source[0] -> m0;
#   measure shared[0] -> m1;
#
#   switch (teleport_fix(m0, m1)) {
#     case 0: { }
#     case 1: { x target; }
#     case 2: { z target; }
#     case 3: { x target; z target; }
#   }
# }
#
# qreg q[1];
# creg c[1];
# teleport q[0];
# measure q[0] -> c[0];

# %%
plus_machine = Machine(teleport_plus, num_qubits=8, registry=reg)
plus_machine.shots("main", 2000).plot_histogram()
